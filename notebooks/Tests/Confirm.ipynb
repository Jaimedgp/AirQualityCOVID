# %%
library(ggplot2)
library(tidyverse)
library(saqgetr)
library(lubridate)
# Out:
# ── Attaching packages ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ tibble  3.0.4     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.0
# ✔ purrr   0.3.4
#
# ── Conflicts ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘lubridate’
#
#
# The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union

# %%
suppressMessages(library(repr))
options(repr.plot.width=25,
        repr.plot.height=10,
        #repr.plot.pointsize=50,
        repr.plot.family='serif'
       )

# %%
spain.sites <- get_saq_sites() %>%
    filter(country == "spain",
           site == "es2010a",
          )

head(spain.sites)
# Out:
#   site    site_name   latitude longitude elevation country country_iso_code
# 1 es2010a LA RUBIA II 41.63    -4.740556 683       spain   ES
#   site_type site_area date_start date_end            network    eu_code
# 1 traffic   urban     2011-04-01 2021-01-16 01:00:00 NET_ES208A STA_ES2010A
#   eoi_code observation_count data_source
# 1 ES2010A  494065            airbase; aqer:e1a; aqer:e2a

# %%
data.haro <- get_saq_observations(site = "es1740a",
                                  start="2010-01-01",
                                  #valid_only = TRUE,
                                  verbose = TRUE
                                 )
# Out:
# 2021-01-28 17:44:19.948 CET: Loading `air_quality_data_site_es1740a_2010.csv.gz`...
#
# 2021-01-28 17:44:20.679 CET: Loading `air_quality_data_site_es1740a_2011.csv.gz`...
#
# 2021-01-28 17:44:21.334 CET: Loading `air_quality_data_site_es1740a_2012.csv.gz`...
#
# 2021-01-28 17:44:22.100 CET: Loading `air_quality_data_site_es1740a_2013.csv.gz`...
#
# 2021-01-28 17:44:23.078 CET: Loading `air_quality_data_site_es1740a_2014.csv.gz`...
#
# 2021-01-28 17:44:23.958 CET: Loading `air_quality_data_site_es1740a_2015.csv.gz`...
#
# 2021-01-28 17:44:24.828 CET: Loading `air_quality_data_site_es1740a_2016.csv.gz`...
#
# 2021-01-28 17:44:25.667 CET: Loading `air_quality_data_site_es1740a_2017.csv.gz`...
#
# 2021-01-28 17:44:26.571 CET: Loading `air_quality_data_site_es1740a_2018.csv.gz`...
#
# 2021-01-28 17:44:27.390 CET: Loading `air_quality_data_site_es1740a_2019.csv.gz`...
#
# 2021-01-28 17:44:28.218 CET: Loading `air_quality_data_site_es1740a_2020.csv.gz`...
#
# 2021-01-28 17:44:29.109 CET: Loading `air_quality_data_site_es1740a_2021.csv.gz`...
#
# 2021-01-28 17:44:29.403 CET: Loading `air_quality_data_site_es1740a_2022.csv.gz`...

# %%
a <- data.haro[data.haro$variable %in% c("no2", "no", "o3", "pm10", "pm2.5"), ]

# %%
head(a)
# Out:
#   date       date_end site    variable process summary validity unit   value
# 1 2010-01-01 <NA>     es1740a pm10     41448   20      1        ug.m-3 12.743
# 2 2010-01-02 <NA>     es1740a pm10     41448   20      1        ug.m-3 18.278
# 3 2010-01-03 <NA>     es1740a pm10     41448   20      1        ug.m-3 15.230
# 4 2010-01-04 <NA>     es1740a pm10     41448   20      1        ug.m-3 26.511
# 5 2010-01-05 <NA>     es1740a pm10     41448   20      1        ug.m-3 19.483
# 6 2010-01-06 <NA>     es1740a pm10     41448   20      1        ug.m-3 16.447

# %%
df <- data.haro[data.haro$variable == "pm10", ]
print(sum(is.na(df$date_end)))
print(length(df$date_end))
head(df)
# Out:
# [1] 26498
# [1] 91014
#   date       date_end site    variable process summary validity unit   value
# 1 2010-01-01 <NA>     es1740a pm10     41448   20      1        ug.m-3 12.743
# 2 2010-01-02 <NA>     es1740a pm10     41448   20      1        ug.m-3 18.278
# 3 2010-01-03 <NA>     es1740a pm10     41448   20      1        ug.m-3 15.230
# 4 2010-01-04 <NA>     es1740a pm10     41448   20      1        ug.m-3 26.511
# 5 2010-01-05 <NA>     es1740a pm10     41448   20      1        ug.m-3 19.483
# 6 2010-01-06 <NA>     es1740a pm10     41448   20      1        ug.m-3 16.447

# %%
min(df$date)
# Out:
# [1] "2010-01-01 UTC"

# %%
max(df$date)
# Out:
# [1] "2020-09-14 09:00:00 UTC"

# %%
df <- df[-which(is.na(df$date_end)), ]

head(df)
# Out:
#   date                date_end            site    variable process summary
# 1 2014-01-01 00:00:00 2014-01-01 01:00:00 es1740a pm10     119025  1
# 2 2014-01-01 01:00:00 2014-01-01 02:00:00 es1740a pm10     119025  1
# 3 2014-01-01 02:00:00 2014-01-01 03:00:00 es1740a pm10     119025  1
# 4 2014-01-01 03:00:00 2014-01-01 04:00:00 es1740a pm10     119025  1
# 5 2014-01-01 04:00:00 2014-01-01 05:00:00 es1740a pm10     119025  1
# 6 2014-01-01 05:00:00 2014-01-01 06:00:00 es1740a pm10     119025  1
#   validity unit   value
# 1 1        ug.m-3 45
# 2 1        ug.m-3 42
# 3 1        ug.m-3 45
# 4 1        ug.m-3 43
# 5 1        ug.m-3 40
# 6 1        ug.m-3 37

# %%
df[which((df$date - df$date_end) != -1),]
# Out:
#      date date_end site variable process summary validity unit value

# %%
resolut <- df$date - df$date_end
sum(resolut)/length(resolut)
# Out:
# Time difference of -1 hours

# %%
min(df$date)
# Out:
# [1] "2014-01-01 UTC"

# %%
max(df$date)
# Out:
# [1] "2020-09-14 09:00:00 UTC"

# %%
miss <- df[year(df$date) == "2013",]# & year(df$date) <= "2014",]
head(miss)
# Out:
#      date date_end site variable process summary validity unit value

# %%
ggplot() +
    geom_line(data=a, aes(x=ymd_hms(date), y=value)) +
               facet_wrap(~variable, ncol=1)
# Out:
# Warning message:
# “Removed 10 row(s) containing missing values (geom_path).”
# plot without title
